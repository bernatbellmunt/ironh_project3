# %%
#Imports


import pandas as pd
from pandas import json_normalize
import requests 
import json
import os
from dotenv import load_dotenv #conda install -c conda-forge python-dotenv
import time
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
from geopy.distance import geodesic as GD

import src.functions as functions

# %%
import os
load_dotenv()
key = os.getenv("4squarekey")

# %%
df = pd.read_csv('src/locations_df.csv')

# %%
df.rename(columns={"Unnamed: 0": "index"}, inplace=True)

# %%
df.drop(columns=["index"],inplace=True)

# %%
# f = 100000 + design * 20/87 * 0.1 + tech * 15/87 * 0.1 - starb * 10/87 * 0.1 - airp * 20/87 *0.15 - clubs * 87/87 * 0.1 
#- vegan * 1/87* 0.05 - school * 26/87 * 0.1 - bask* 1/87*0.05 - dog * 0.05*1/87 - cost * 87/87 *0.1 - wage * 87/87 * 0.1

# %%
rank = []
for index,row in df.iterrows():
    formula = 10 + row["nº design comp"] * 20/87 * 0.1 + row["nº tech (>$1M)"] * 15/87 * 0.1 - row["dist to starbucks (km)"] * 10/87 * 0.1 - row["dist to airport (km)"] * 20/87 *0.15 - row["average dist to clubs (km)"] * 87/87 * 0.1 - row["average dist to vegan rest. (km)"]*1/87 * 0.05 - row["average dist to schools (km)"] * 26/87 * 0.1 - row["dist. to closes basketball court (km)"]*1/87 *0.05 - row["dist. to closest canine salon (km)"]*1/87 * 0.05 - row["cost living index"] / row["avg_wage"] * 87/87 * 0.2
    rank.append(formula)
rank
        
df["rank"] = rank
df
# Out:
#                        name       city country   latitude   longitude  \
# 0                      Lala  Palo Alto     USA  37.451151 -122.154369
# 1                   PodTech  Palo Alto     USA  37.408256 -122.154176
# 2                 SonicSwap  Palo Alto     USA  37.444487 -122.163979
# 3                MyMiniLife  Palo Alto     USA  37.437328 -122.159928
# 4                   Mytopia  Palo Alto     USA  34.007967 -118.489681
# ..                      ...        ...     ...        ...         ...
# 203             BAM Studios    Chicago     USA  41.893622  -87.627423
# 204                 Plugola    Chicago     USA  41.907542  -87.662990
# 205            Midway Games    Chicago     USA  41.879535  -87.624333
# 206  Blizzard Entertainment     Irvine     USA  33.669500 -117.822200
# 207            DanceShowoff     Irvine     USA  33.671428 -117.791423
#
#      nº design comp  nº tech (>$1M)  dist to starbucks (km)  \
# 0                 6               4                   0.729
# ...

# %%
df.sort_values(by=['rank'], ascending= False, inplace=True)
df
# Out:
#                    name           city country   latitude   longitude  \
# 112  Unity Technologies  San Francisco     USA  55.692461   12.530107
# 62             Babelgum         London     GBR  53.344104   -6.267494
# 94               Sutros  San Francisco     USA  37.756922 -122.420870
# 87             DanceJam  San Francisco     USA  37.781557 -122.407959
# 173              Vibeex          Paris     FRA  48.856667    2.350987
# ..                  ...            ...     ...        ...         ...
# 145    Verismo Networks  Mountain View     USA  37.387434 -122.051793
# 9                Veeple      Palo Alto     USA  37.421142 -122.101182
# 142            PicksPal  Mountain View     USA  37.400470 -122.072981
# 143               Raptr  Mountain View     USA  37.403840 -122.078080
# 140              PeerMe  Mountain View     USA  37.419819 -122.090188
#
#      nº design comp  nº tech (>$1M)  dist to starbucks (km)  \
# 112              12              24                   2.726
# ...

# %% [markdown]
# ### There are coordenates that don't meet the city --> I will remove these ones

# %%
real_country=[]
for index,row in df.iterrows():
    real_country.append(functions.check_coord(row["latitude"],row["longitude"]))

# %%
a = df["country"]
prova = pd.DataFrame({"country DB":a, "country 4Sq":real_country})

# %%
prova.head(10)
# Out:
#     country DB country 4Sq
# 112        USA        [DK]
# 62         GBR        [IE]
# 94         USA        [US]
# 87         USA        [US]
# 173        FRA        [FR]
# 86         USA        [US]
# 79         USA        [US]
# 84         USA        [US]
# 110        USA        [US]
# 99         USA        [US]

# %% [markdown]
# #### I remove the two first companies, my locations do not match the city, nor country, so they will be excluded from the analysis

# %%
df = df.iloc[2:]
df
# Out:
#                  name           city country   latitude   longitude  \
# 94             Sutros  San Francisco     USA  37.756922 -122.420870
# 87           DanceJam  San Francisco     USA  37.781557 -122.407959
# 173            Vibeex          Paris     FRA  48.856667    2.350987
# 86         Kongregate  San Francisco     USA  37.786942 -122.401245
# 79               Kyte  San Francisco     USA  37.788482 -122.409173
# ..                ...            ...     ...        ...         ...
# 145  Verismo Networks  Mountain View     USA  37.387434 -122.051793
# 9              Veeple      Palo Alto     USA  37.421142 -122.101182
# 142          PicksPal  Mountain View     USA  37.400470 -122.072981
# 143             Raptr  Mountain View     USA  37.403840 -122.078080
# 140            PeerMe  Mountain View     USA  37.419819 -122.090188
#
#      nº design comp  nº tech (>$1M)  dist to starbucks (km)  \
# 94               12              24                   1.143
# ...

# %% [markdown]
# ### My cities is: San Francisco

# %%
top_choice = df[:1]
top_choice.reset_index(inplace=True)
top_choice.drop(columns=["index"],inplace=True)
top_choice
# Out:
# /var/folders/7s/v9wty4qj3t1cw493y3p29dbc0000gn/T/ipykernel_61702/439183255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_choice.drop(columns=["index"],inplace=True)
#      name           city country   latitude  longitude  nº design comp  \
# 0  Sutros  San Francisco     USA  37.756922 -122.42087              12
#
#    nº tech (>$1M)  dist to starbucks (km)  dist to airport (km)  \
# 0              24                   1.143                15.857
#
#    average dist to clubs (km)  average dist to vegan rest. (km)  \
# 0                      1.0583                          7.321222
#
#    average dist to schools (km)  dist. to closes basketball court (km)  \
# 0                         1.174                                  1.762
#
# ...

# %% [markdown]
# ### Option 1: Sutros, San Francisco, USA, lat=37.756922, long=-122.420870

# %%
lat = 37.756922
long = -122.420870

map_1 = Map(location=[lat, long], zoom_start=15)

# %%
# Define icons
iconoffice = Icon(color = "orange",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-solid fa-building",
            icon_color = "black")

iconostarbucks = Icon(color = "darkgreen",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-coffee",
            icon_color = "white")

iconoairport = Icon(color = "black",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-solid fa-plane",
            icon_color = "white")
iconoclub = Icon(color = "white",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-glass",
            icon_color = "black")
iconovegan = Icon(color = "green",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-leaf",
            icon_color = "white")
iconoschool = Icon(color = "lightgray",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-graduation-cap",
            icon_color = "black")
iconobasket= Icon(color = "darkblue",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-bomb",
            icon_color = "white")
iconodog = Icon(color = "darkred",
            opacity = 0.1,
            prefix = "fa",
            icon = "fa-solid fa-dog",
            icon_color = "white")

# %%
myoffice = Marker(
    location = [lat,long],
    tooltip = "My Office",
    icon=iconoffice)

# %%
starbucks = Marker(
    location = functions.get_query_coordenades("starbucks",lat,long),
    tooltip = "Starbucks Coffee",
    icon=iconostarbucks)

# %%
airport = Marker(
    location = functions.get_query_coordenades("airport",lat,long),
    tooltip = "Airport",
    icon=iconoairport)

# %%
nightclub = Marker(
    location = functions.get_query_coordenades("night club",lat,long),
    tooltip = "Night Club",
    icon=iconoclub)

# %%
vegan = Marker(
    location = functions.get_query_coordenades("vegan",lat,long),
    tooltip = "Vegan Rest.",
    icon=iconovegan)

# %%
school = Marker(
    location = functions.get_query_coordenades("school",lat,long),
    tooltip = "School",
    icon=iconoschool)

# %%
basketball = Marker(
    location = functions.get_query_coordenades("basketball stadium",lat,long),
    tooltip = "Basketball Stadium",
    icon=iconobasket)

# %%
dog = Marker(
    location = functions.get_query_coordenades("salon dog",lat,long),
    tooltip = "Dog Salon",
    icon=iconodog)

# %%
# I add Marker office to map


myoffice.add_to(map_1)
starbucks.add_to(map_1)
airport.add_to(map_1)
nightclub.add_to(map_1)
vegan.add_to(map_1)
school.add_to(map_1)
basketball.add_to(map_1)
dog.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### All criterias are met, welcome to your new office
# 3258-3300 21st St, San Francisco, CA 94110, USA
